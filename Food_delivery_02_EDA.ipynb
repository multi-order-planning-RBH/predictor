# %% [markdown]
# # 1. Import libraries

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2. Load data

# %%
df = pd.read_csv('Sample 14days_food_delivery_All.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 27 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   JobAcceptedDate                                    10000 non-null  object
#  1   calledMerchantTime                                 10000 non-null  object
#  2   arrivedAtMerchantTime                              10000 non-null  object
#  3   mealPickedUpTime                                   10000 non-null  object
#  4   arrivedAtCustLocationTime                          10000 non-null  object
#  5   foodDeliveredTime                                  10000 non-null  object
#  6   riderInitial.lat                                   10000 non-null  float64
#  7   riderInitial.long                                  10000 non-null  float64
# ...

# %% [markdown]
# # 3. plot data distribution

# %% [markdown]
# ## 3.1 lat, long

# %%
df[['riderInitial.lat', 'riderInitial.long']].describe()
# Out:
#        riderInitial.lat  riderInitial.long
# count      10000.000000       10000.000000
# mean          13.824150         100.558029
# std            0.002992           0.006840
# min           13.818988         100.546082
# 25%           13.821548         100.552167
# 50%           13.824201         100.558080
# 75%           13.826701         100.563998
# max           13.829296         100.569729

# %%
plt.figure(figsize=(10, 10))
plt.scatter(
    x=df['riderInitial.lat'],
    y=df['riderInitial.long'],
    alpha=0.2
)
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.scatter(
    x=df['Merchant.Lat'],
    y=df['Merchant.Lng'],
    alpha=0.2
)
plt.show()

# %%
plt.scatter(
    x=df['Customer.lat'],
    y=df['Customer.lng'],
    alpha=0.2
)
plt.show()

# %%
df['calledMerchantTime_to_arrivedAtMerchantTime (m)'].hist(bins=50)
# Out:
# <AxesSubplot: >

# %%
df['mealPickedUpTime_to_arrivedAtCustLocationTime (m)'].hist(bins=50)
# Out:
# <AxesSubplot: >

# %%
df[['riderInitial_to_Merchant_EucDistance','calledMerchantTime_to_arrivedAtMerchantTime (m)']].corr()
# Out:
#                                                  riderInitial_to_Merchant_EucDistance  \
# riderInitial_to_Merchant_EucDistance                                         1.000000
# calledMerchantTime_to_arrivedAtMerchantTime (m)                              0.760255
#
#                                                  calledMerchantTime_to_arrivedAtMerchantTime (m)
# riderInitial_to_Merchant_EucDistance                                                    0.760255
# calledMerchantTime_to_arrivedAtMerchantTime (m)                                         1.000000

# %%
plt.scatter(
    x=df['riderInitial_to_Merchant_EucDistance'],
    y=df['calledMerchantTime_to_arrivedAtMerchantTime (m)'],
    alpha=0.2
)
plt.show()

# %%
df[['riderInitial_to_Merchant_ShortestDistance','calledMerchantTime_to_arrivedAtMerchantTime (m)']].corr()
# Out:
#                                                  riderInitial_to_Merchant_ShortestDistance  \
# riderInitial_to_Merchant_ShortestDistance                                          1.00000
# calledMerchantTime_to_arrivedAtMerchantTime (m)                                    0.50537
#
#                                                  calledMerchantTime_to_arrivedAtMerchantTime (m)
# riderInitial_to_Merchant_ShortestDistance                                                0.50537
# calledMerchantTime_to_arrivedAtMerchantTime (m)                                          1.00000

# %%
plt.scatter(
    x=df['riderInitial_to_Merchant_ShortestDistance'],
    y=df['calledMerchantTime_to_arrivedAtMerchantTime (m)'],
    alpha=0.2
)
plt.show()

# %%
df[['Merchant_to_Customer_EucDistance', 'mealPickedUpTime_to_arrivedAtCustLocationTime (m)']].corr()
# Out:
#                                                    Merchant_to_Customer_EucDistance  \
# Merchant_to_Customer_EucDistance                                           1.000000
# mealPickedUpTime_to_arrivedAtCustLocationTime (m)                          0.885786
#
#                                                    mealPickedUpTime_to_arrivedAtCustLocationTime (m)
# Merchant_to_Customer_EucDistance                                                            0.885786
# mealPickedUpTime_to_arrivedAtCustLocationTime (m)                                           1.000000

# %%
plt.scatter(
    x=df['Merchant_to_Customer_EucDistance'],
    y=df['mealPickedUpTime_to_arrivedAtCustLocationTime (m)'],
    alpha=0.2
)
plt.show()

# %%
df[['Merchant_to_Customer_ShortestDistance', 'mealPickedUpTime_to_arrivedAtCustLocationTime (m)']].corr()
# Out:
#                                                    Merchant_to_Customer_ShortestDistance  \
# Merchant_to_Customer_ShortestDistance                                           1.000000
# mealPickedUpTime_to_arrivedAtCustLocationTime (m)                               0.804998
#
#                                                    mealPickedUpTime_to_arrivedAtCustLocationTime (m)
# Merchant_to_Customer_ShortestDistance                                                       0.804998
# mealPickedUpTime_to_arrivedAtCustLocationTime (m)                                           1.000000

# %%
plt.scatter(
    x=df['Merchant_to_Customer_ShortestDistance'],
    y=df['mealPickedUpTime_to_arrivedAtCustLocationTime (m)'],
    alpha=0.2
)
plt.show()
